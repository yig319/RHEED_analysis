# %%
import sys
import numpy as np
from scipy import special
from matplotlib import (pyplot as plt, animation, colors, ticker, path, patches, patheffects)
sys.path.append('../')
from visualize_functions import visualize_afm_image

# %% [markdown]
# ### Sample: t43

# %%
img = np.loadtxt('../afm_figures/t43-substrate.txt')[:256]

scalebar_dict = {'image_size': 5000, 'scale_size': 1000, 'units': 'nm'}
visualize_afm_image(img, colorbar_range=[-5e-10, 5e-10], scalebar_dict=scalebar_dict, 
                    filename='../afm_figures/t43_substrate-colorbar.svg')

# %%
img = np.loadtxt('../afm_figures/t43-film.txt')[:256]

scalebar_dict = {'image_size': 2008, 'scale_size': 500, 'units': 'nm'}
visualize_afm_image(img, colorbar_range=[-5e-10, 5e-10], scalebar_dict=scalebar_dict, 
                   filename='../afm_figures/t43_film-colorbar.svg')

# %% [markdown]
# ### Sample: t11

# %%
img = np.loadtxt('../afm_figures/t11-substrate.txt')[:256]

scalebar_dict = {'image_size': 5000, 'scale_size': 1000, 'units': 'nm'}
visualize_afm_image(img, colorbar_range=[-3e-10, 3e-10], scalebar_dict=scalebar_dict, 
                   filename='../afm_figures/t11_substrate-colorbar.svg')

# %%
img = np.loadtxt('../afm_figures/t11-film.txt')[:256]

scalebar_dict = {'image_size': 2000, 'scale_size': 500, 'units': 'nm'}
visualize_afm_image(img, colorbar_range=[-5e-10, 5e-10], scalebar_dict=scalebar_dict, 
                   filename='../afm_figures/t11_film-colorbar.svg')

# %% [markdown]
# ### Sample: t28

# %%
img = np.loadtxt('../afm_figures/u28-substrate.txt')[:256]

scalebar_dict = {'image_size': 5000, 'scale_size': 1000, 'units': 'nm'}
visualize_afm_image(img, colorbar_range=[-5e-10, 5e-10], scalebar_dict=scalebar_dict, 
                   filename='../afm_figures/u28_substrate-colorbar.svg')

# %%
img = np.loadtxt('../afm_figures/u28-film.txt')[:256]

scalebar_dict = {'image_size': 2000, 'scale_size': 500, 'units': 'nm'}
visualize_afm_image(img, colorbar_range=[-5e-10, 5e-10], scalebar_dict=scalebar_dict, 
                   filename='../afm_figures/u28_film-colorbar.svg')
